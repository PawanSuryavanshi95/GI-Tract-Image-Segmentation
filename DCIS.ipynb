# %% [markdown]
# ### Downloading Data ( Run Once )

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download uw-madison-gi-tract-image-segmentation
# Out:
# Downloading uw-madison-gi-tract-image-segmentation.zip to /content
#  99% 2.28G/2.30G [00:29<00:00, 93.1MB/s]
# 100% 2.30G/2.30G [00:29<00:00, 82.4MB/s]

# %%
# !unzip -h
# Out:
# UnZip 6.00 of 20 April 2009, by Debian. Original by Info-ZIP.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
#   -j  junk paths (do not make directories)   -aa treat ALL files as text
#   -U  use escapes for all non-ASCII Unicode  -UU ignore any Unicode fields
#   -C  match filenames case-insensitively     -L  make (some) names lowercase
#   -X  restore UID/GID info                   -V  retain VMS version numbers
#   -K  keep setuid/setgid/tacky permissions   -M  pipe through "more" pager
#   -O CHARSET  specify a character encoding for DOS, Windows and OS/2 archives
#   -I CHARSET  specify a character encoding for UNIX and other archives
#
# See "unzip -hh" or unzip.txt for more help.  Examples:
#   unzip data1 -x joe   => extract all files except joe from zipfile data1.zip
#   unzip -p foo | more  => send contents of foo.zip via pipe into program more
#   unzip -fo foo ReadMe => quietly replace existing ReadMe if archive file newer

# %%
! unzip '/content/uw-madison-gi-tract-image-segmentation.zip' -d '/content/drive/MyDrive/Datasets'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0121_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0122_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0123_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0124_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0125_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0126_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0127_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0128_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0129_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0130_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0131_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0132_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0133_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0134_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0135_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0136_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0137_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0138_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0139_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0140_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0141_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0142_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0143_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case77/case77_day20/scans/slice_0144_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0001_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0002_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0003_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0004_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0005_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0006_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0007_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0008_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0009_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0010_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0011_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0012_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0013_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0014_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0015_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0016_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0017_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0018_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0019_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0020_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0021_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0022_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0023_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0024_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0025_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0026_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0027_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0028_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0029_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0030_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0031_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0032_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0033_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0034_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0035_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0036_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0037_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0038_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0039_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0040_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0041_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0042_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0043_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0044_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0045_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0046_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0047_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0048_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0049_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0050_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0051_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0052_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0053_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0054_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0055_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0056_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0057_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0058_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0059_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0060_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0061_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0062_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0063_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0064_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0065_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0066_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0067_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0068_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0069_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0070_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0071_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0072_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0073_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0074_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0075_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0076_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0077_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0078_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0079_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0080_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0081_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0082_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0083_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0084_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0085_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0086_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0087_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0088_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0089_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0090_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0091_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0092_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0093_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0094_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0095_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0096_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0097_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0098_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0099_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0100_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0101_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0102_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0103_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0104_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0105_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0106_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0107_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0108_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0109_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0110_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0111_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_0112_360_310_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case78/case78_day0/scans/slice_
266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0068_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0069_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0070_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0071_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0072_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0073_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0074_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0075_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0076_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0077_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0078_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0079_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0080_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0081_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0082_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0083_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0084_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0085_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0086_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0087_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0088_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0089_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0090_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0091_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0092_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0093_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0094_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0095_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0096_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0097_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0098_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0099_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0100_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0101_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0102_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0103_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0104_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0105_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0106_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0107_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0108_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0109_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0110_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0111_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0112_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0113_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0114_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0115_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0116_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0117_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0118_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0119_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0120_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0121_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0122_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0123_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0124_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0125_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0126_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0127_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0128_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0129_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0130_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0131_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0132_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0133_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0134_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0135_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0136_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0137_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0138_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0139_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0140_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0141_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0142_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0143_266_266_1.50_1.50.png
#   inflating: /content/drive/MyDrive/Datasets/train/case92/case92_day0/scans/slice_0144_266_266_1.50_1.50.png

# %% [markdown]
# ### Initialize

# %%
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
from torch import nn
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, TensorDataset
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from tqdm import tqdm
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
path = '/content/drive/MyDrive/Datasets'

# %%
label = 'stomach'

# %%
batch_size = 32
lr = 0.001

# %%
def getMasks(mask_index, mask_data, category = 'stomach'):
  masks = []
  mask_image= []

  num = 0

  for i in mask_index:
    masks.append(mask_data[i])

  for rle, shape in masks:

    x = list(map(int, rle.split(' ')))

    width,height = shape

    y = np.zeros((width*height))
    
    k = 0
    while k < len(x):
      i = 0
      while i < x[k+1]:
        y[x[k]-1 + i] = 1
        i = i + 1
      k = k + 2

    y = np.reshape(y, (width, height))
    y = cv2.resize(y, (256,256))

    mask_image.append(y)

    num = num + 1
    if num % 1000 == 0: print(num)

  mask_image = np.asarray(mask_image)

  return mask_image

# %% [markdown]
# ### Preparing Data ( Run Once )

# %%
df = pd.read_csv(path + '/train.csv')

# %%
df.head()
# Out:
#                          id        class segmentation
# 0  case123_day20_slice_0001  large_bowel          NaN
# 1  case123_day20_slice_0001  small_bowel          NaN
# 2  case123_day20_slice_0001      stomach          NaN
# 3  case123_day20_slice_0002  large_bowel          NaN
# 4  case123_day20_slice_0002  small_bowel          NaN

# %%
df.size
# Out:
# 346464

# %%
df = df.dropna()

# %%
df.size
# Out:
# 101739

# %%
df.head()
# Out:
#                            id    class  \
# 194  case123_day20_slice_0065  stomach
# 197  case123_day20_slice_0066  stomach
# 200  case123_day20_slice_0067  stomach
# 203  case123_day20_slice_0068  stomach
# 206  case123_day20_slice_0069  stomach
#
#                                           segmentation
# 194  28094 3 28358 7 28623 9 28889 9 29155 9 29421 ...
# 197  27561 8 27825 11 28090 13 28355 14 28620 15 28...
# 200  15323 4 15587 8 15852 10 16117 11 16383 12 166...
# 203  14792 5 15056 9 15321 11 15587 11 15852 13 161...
# 206  14526 6 14789 12 15054 14 15319 16 15584 17 15...

# %%
label_mapping = {
    'large_bowel': 0,
    'small_bowel': 1,
    'stomach': 2,
}

rlabel_mapping = {
    0: 'large_bowel',
    1: 'small_bowel',
    2: 'stomach',
}

# %%
def getImages(category = 'stomach'):
  images_shape = []
  images = []
  mask_data = []
  mask_index = []

  num = 0

  i = 0

  for index, row in df.iterrows():

    if row[1]!=category: continue

    imgs_path = path + '/train/' + row[0].split('_')[0] + '/' + row[0].split('_')[0] + '_' + row[0].split('_')[1] + '/scans/'

    img = []

    for img_file in os.listdir(imgs_path):

      if img_file.split('_')[1] == row[0].split('_')[3]:

        img = cv2.imread(imgs_path + img_file, cv2.IMREAD_GRAYSCALE)

        images_shape.append(img.shape)
        mask_data.append((row[2],img.shape))
        mask_index.append(i)

        i = i + 1

        img = cv2.resize(img, (256,256))
        img = np.array(img)

        images.append(img)
        break

    num = num + 1
    if num % 1000 == 0: print(num)

  images = np.asarray(images)

  return (images, mask_data, mask_index)

# %%
(images, mask_data, mask_index) = getImages(category = label)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-a1aea2eeb2ce> in <module>()
# ----> 1 (images, mask_data, mask_index) = getImages(category = label)
#
# <ipython-input-37-4faafe01cf63> in getImages(category)
#      17     img = []
#      18
# ---> 19     for img_file in os.listdir(imgs_path):
#      20
#      21       if img_file.split('_')[1] == row[0].split('_')[3]:
#
# KeyboardInterrupt:

# %%
plt.imshow(images[4])

# %%
images = torch.from_numpy(images)
torch.save(images, path + '/' + label + '_X.pt')

# %%
masks = getMasks([mask_index[4]], mask_data, category = label)

# %%
plt.imshow(masks[0])

# %%
mask_index2 = np.asarray(mask_index)
mask_index2 = torch.from_numpy(mask_index2)
torch.save(mask_index2, path + '/' + label + '_Y.pt')

# %%
stomach_mask_data = pd.DataFrame(mask_data)
stomach_mask_data.to_csv(path + '/mask_data_' + label + '.csv')

# %% [markdown]
# ### Loading Data

# %%
images = torch.load(path + '/' + label + '_X.pt')

# %%
mask_index = torch.load(path + '/' + label + '_Y.pt')

# %%
df2 = pd.read_csv(path + '/mask_data_' + label + '.csv')

# %%
mask_data = []
for index, row in df2.iterrows():
  shape = tuple(map(int, row[2][1:-1].split(', ')))
  mask_data.append((row[1],shape))

# %%
# For testing
masks = getMasks([mask_index[4]], mask_data, category = label)
plt.imshow(masks[0])

# %%
X = images.numpy()
y = mask_index.numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train = torch.from_numpy(X_train)
y_train = torch.from_numpy(y_train)
y_test = torch.from_numpy(y_test)
x_test = torch.from_numpy(X_test)

# %%
print(X_train.dtype)
print(y_train.dtype)
# Out:
# torch.uint8
# torch.int64

# %%
X_train.shape
# Out:
# torch.Size([6470, 256, 256])

# %%
x_test.shape
# Out:
# torch.Size([2157, 256, 256])

# %%
class GITract(Dataset):
    def __init__(self, tensors, transform=False):
        self.tensors = tensors
        self.transform = transform
        
    def __len__(self):
        return self.tensors[0].shape[0]

    def __getitem__(self, idx):
        return (self.tensors[0][idx], self.tensors[1][idx])

# %%
train_set = GITract(tensors=(X_train, y_train))
test_set = GITract(tensors=(X_test, y_test))

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %% [markdown]
# ### Model Architecture

# %%
def double_conv(in_c, out_c):
  conv = nn. Sequential(
    nn.Conv2d (in_c, out_c, kernel_size=3, padding = 1),
    nn.ReLU(inplace=True),
    nn.BatchNorm2d(out_c),
    nn.Conv2d(out_c, out_c, kernel_size=3, padding = 1),
    nn.ReLU(inplace=True),
    nn.BatchNorm2d(out_c),
  )
  return conv

# %%
class UNet(nn.Module):
  def __init__(self):
      super(UNet, self).__init__()
      
      self.max_pool_2x2 = nn.MaxPool2d(kernel_size=2, stride=2)
      self.down_conv_1 = double_conv(1,64)
      self.down_conv_2 = double_conv(64,128)
      self.down_conv_3 = double_conv(128,256)
      self.down_conv_4 = double_conv(256,512)

      self.down_conv_5 = double_conv(512, 1024)

      self.up_trans_1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
      self.up_conv_1 = double_conv(1024,512)

      self.up_trans_2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
      self.up_conv_2 = double_conv(512,256)

      self.up_trans_3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
      self.up_conv_3 = double_conv(256,128)

      self.up_trans_4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
      self.up_conv_4 = double_conv(128,64)

      self.out = nn.Conv2d(64, 1, kernel_size=1)

      self.sig = nn.Sigmoid()


  def forward(self, image):
    
    x1 = self.down_conv_1(image)
    x11 = self.max_pool_2x2(x1)

    #print(x11.shape)

    x2 = self.down_conv_2(x11)
    x22 = self.max_pool_2x2(x2)

    #print(x22.shape)

    x3 = self.down_conv_3(x22)
    x33 = self.max_pool_2x2(x3)

    #print(x33.shape)

    x4 = self.down_conv_4(x33)
    x44 = self.max_pool_2x2(x4)

    x5 = self.down_conv_5(x44)

    #print(x5.shape)

    y1 = self.up_trans_1(x5)
    y11 = self.up_conv_1(torch.cat([y1, x4], 1))

    #print(y11.shape)

    y2 = self.up_trans_2(y11)
    y22 = self.up_conv_2(torch.cat([y2, x3], 1))

    #print(y22.shape)

    y3 = self.up_trans_3(y22)
    y33 = self.up_conv_3(torch.cat([y3, x2], 1))

    #print(y33.shape)

    y4 = self.up_trans_4(y33)
    y44 = self.up_conv_4(torch.cat([y4, x1], 1))

    #print(y44.shape)


    x = self.out(y44)

    x = self.sig(x)

    #print(x.shape)

    return x

# %%
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    
    self.max_pool_2x2 = nn.MaxPool2d(kernel_size=2, stride=2)

    self.conv_1 = nn.Conv2d (1, 16, kernel_size=7, padding = 1)
    self.conv_2 = nn.Conv2d (16, 16, kernel_size=7, padding = 1)

    self.conv_3 = nn.Conv2d (16, 32, kernel_size=5, padding = 1)
    self.conv_4 = nn.Conv2d (32, 32, kernel_size=5, padding = 1)
    self.conv_5 = nn.Conv2d (32, 32, kernel_size=5, padding = 1)
    self.conv_6 = nn.Conv2d (32, 32, kernel_size=5, padding = 1)

    self.conv_7 = nn.Conv2d (32, 64, kernel_size=5, padding = 1)
    self.conv_8 = nn.Conv2d (64, 64, kernel_size=5, padding = 1)
      
    self.fc = nn.Linear(64*11*11, 128*128)

    self.sig = nn.Sigmoid()


  def forward(self, image):
    
    x = F.relu(self.conv_1(image))
    x = F.relu(self.conv_2(x))

    x = self.max_pool_2x2(x)

    x = F.relu(self.conv_3(x))
    x = F.relu(self.conv_4(x))
    x = F.relu(self.conv_5(x))
    x = F.relu(self.conv_6(x))

    x = self.max_pool_2x2(x)

    x = F.relu(self.conv_7(x))
    x = F.relu(self.conv_8(x))
    
    x = self.max_pool_2x2(x)

    print(x.shape)

    x = x.view(-1, 64*11*11)

    x = self.fc(x)

    x = self.sig(x)


    return x

# %% [markdown]
# ### Training

# %%
model = UNet().to(device)
from torchsummary import summary

summary(model, (1, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64,
#       BatchNorm2d-48          [-1, 256, 64, 64]             512
#   ConvTranspose2d-49        [-1, 128, 128, 128]         131,200
#            Conv2d-50        [-1, 128, 128, 128]         295,040
#              ReLU-51        [-1, 128, 128, 128]               0
#       BatchNorm2d-52        [-1, 128, 128, 128]             256
#            Conv2d-53        [-1, 128, 128, 128]         147,584
#              ReLU-54        [-1, 128, 128, 128]               0
#       BatchNorm2d-55        [-1, 128, 128, 128]             256
#   ConvTranspose2d-56         [-1, 64, 256, 256]          32,832
#            Conv2d-57         [-1, 64, 256, 256]          73,792
#              ReLU-58         [-1, 64, 256, 256]               0
#       BatchNorm2d-59         [-1, 64, 256, 256]             128
#            Conv2d-60         [-1, 64, 256, 256]          36,928
#              ReLU-61         [-1, 64, 256, 256]               0
#       BatchNorm2d-62         [-1, 64, 256, 256]             128
#            Conv2d-63          [-1, 1, 256, 256]              65
#           Sigmoid-64          [-1, 1, 256, 256]               0
# ================================================================
# Total params: 31,042,369
# Trainable params: 31,042,369
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.25
# Forward/backward pass size (MB): 808.00
# Params size (MB): 118.42
# Estimated Total Size (MB): 926.67
# ----------------------------------------------------------------

# %%
checkpoint = torch.load(path + '/models/' + label + '/unet_stomach_25.pt')

# %%
load = True

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

n_total_steps = len(train_loader)
epochloss = 0
running = 0
losslist = list()

ep = 0

if load:
  model.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  ep = checkpoint['epoch']

epochs = 20

for epoch in range(epochs):

  print("Epoch {}/{} :".format(epoch, epochs))

  for i, (images, index) in enumerate(train_loader):
    images = images/255
    images = 1 - images
    images = torch.reshape(images, (images.shape[0], 1, images.shape[1], images.shape[2]))
  
    images = images.to(device)

    index_array = index.numpy()

    masks = getMasks(index_array, mask_data)
    masks = masks.astype('float32')
    masks = torch.from_numpy(masks)
    masks = masks/1

    masks = torch.reshape(masks, (masks.shape[0], 1, masks.shape[1], masks.shape[2]))
    masks = masks.to(device)

    outputs = model(images)

    loss = criterion(outputs, masks)

    epochloss += loss
    running += loss

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (i+1) % int(n_total_steps/5) == 0:
      print (f'     Step [{i+1}/{n_total_steps}], Loss: {running/int(n_total_steps/5)}')
      running = 0
  
  if (epoch+1)%5==0:
    torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            }, path + '/models/' + label + '/unet_stomach_' + str(epoch + ep) + '.pt')
  
  losslist.append(epochloss/n_total_steps)
  epochloss=0
# Out:
# Epoch 0/20 :
#      Step [40/203], Loss: 0.007612406741827726
#      Step [80/203], Loss: 0.007916263304650784
#      Step [120/203], Loss: 0.007873299531638622
#      Step [160/203], Loss: 0.007470907177776098
#      Step [200/203], Loss: 0.0075165689922869205
# Epoch 1/20 :
#      Step [40/203], Loss: 0.007608221378177404
#      Step [80/203], Loss: 0.006998676806688309
#      Step [120/203], Loss: 0.007230112794786692
#      Step [160/203], Loss: 0.007244893815368414
#      Step [200/203], Loss: 0.006985427346080542
# Epoch 2/20 :
#      Step [40/203], Loss: 0.007064980920404196
#      Step [80/203], Loss: 0.006645126733928919
#      Step [40/203], Loss: 0.004432518966495991
#      Step [80/203], Loss: 0.00391422351822257
#      Step [120/203], Loss: 0.003986789844930172
#      Step [160/203], Loss: 0.004071998875588179
#      Step [200/203], Loss: 0.004121802281588316
# Epoch 15/20 :
#      Step [40/203], Loss: 0.00442472705617547
#      Step [80/203], Loss: 0.003827745094895363
#      Step [120/203], Loss: 0.003789863782003522
#      Step [160/203], Loss: 0.004238748457282782
#      Step [200/203], Loss: 0.004165738821029663
# Epoch 16/20 :
#      Step [40/203], Loss: 0.004318297374993563
#      Step [80/203], Loss: 0.00361234019510448
#      Step [120/203], Loss: 0.003927628975361586
#      Step [160/203], Loss: 0.004341738764196634
#      Step [200/203], Loss: 0.0042965165339410305
# Epoch 17/20 :
#      Step [40/203], Loss: 0.004250878933817148
#      Step [80/203], Loss: 0.003792510135099292
#      Step [120/203], Loss: 0.0038967032451182604
#      Step [160/203], Loss: 0.004101878497749567
#      Step [200/203], Loss: 0.004165966995060444
# Epoch 18/20 :
#      Step [40/203], Loss: 0.0041391863487660885
#      Step [80/203], Loss: 0.0036436354275792837
#      Step [120/203], Loss: 0.00370233366265893
#      Step [160/203], Loss: 0.003890079213306308
#      Step [200/203], Loss: 0.004403745289891958
# Epoch 19/20 :
#      Step [40/203], Loss: 0.004052142612636089
#      Step [80/203], Loss: 0.003828666405752301
#      Step [120/203], Loss: 0.0034182078670710325
#      Step [160/203], Loss: 0.003598734736442566
#      Step [200/203], Loss: 0.004079452715814114

# %% [markdown]
# ### Testing

# %%
model = UNet().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

checkpoint = torch.load(path + '/models/' + label + '/unet_stomach_25.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
ep = checkpoint['epoch']

# %%
model.eval()
# Out:
# UNet(
#   (max_pool_2x2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (down_conv_1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (down_conv_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (down_conv_3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (down_conv_4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (down_conv_5): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (up_trans_1): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#   (up_conv_1): Sequential(
#     (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (up_trans_2): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (up_conv_2): Sequential(
#     (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (up_trans_3): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (up_conv_3): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (up_trans_4): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (up_conv_4): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (out): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   (sig): Sigmoid()
# )

# %%
a = np.array([np.zeros((1,256,256))])
b = np.array([np.zeros((1,256,256))])
c = np.array([np.zeros((1,256,256))])

for i, (images, index) in enumerate(test_loader):
  images = images/255
  images = 1 - images
  images = torch.reshape(images, (images.shape[0], 1, images.shape[1], images.shape[2]))
  a = a + images.numpy()
  images = images.to(device)

  index_array = index.numpy()

  masks = getMasks(index_array, mask_data)
  masks = torch.from_numpy(masks)
  masks = torch.reshape(masks, (masks.shape[0], 1, masks.shape[1], masks.shape[2]))
  b = b + masks.numpy()
  masks = masks.to(device)

  outputs = model(images)

  c = c + outputs.cpu().detach().numpy()
  break

# %%
a.shape
# Out:
# (32, 1, 256, 256)

# %%
b.shape
# Out:
# (32, 1, 256, 256)

# %%
c.shape
# Out:
# (32, 1, 256, 256)

# %%
plt.imshow(a[13].reshape((256,256)), cmap="gray")

# %%
plt.imshow(b[13].reshape((256,256)), cmap="gray")

# %%
plt.imshow(c[13].reshape((256,256)), cmap="gray")
